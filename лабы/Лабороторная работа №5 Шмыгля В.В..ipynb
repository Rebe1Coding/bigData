# %% [markdown]
# ![photo_2024-12-18_09-36-12.jpg](data:image/jpeg;base64,...)![photo_2024-12-18_09-36-01.jpg](data:image/jpeg;base64,...)Что бы запустить Hadoop Google Colab надо предваритьльно провести некоторые доп установки но Google Colab не даст нам этого сделать в бесплатной версии более того если запускать все по порядку он будет выдавать предупреждения о блокировки

# %%
# !java -version
# Out:
# openjdk version "11.0.25" 2024-10-15
# OpenJDK Runtime Environment (build 11.0.25+9-post-Ubuntu-1ubuntu122.04)
# OpenJDK 64-Bit Server VM (build 11.0.25+9-post-Ubuntu-1ubuntu122.04, mixed mode, sharing)

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !update-alternatives --config java
# Out:
# There are 2 choices for the alternative java (providing /usr/bin/java).
#
#   Selection    Path                                            Priority   Status
# ------------------------------------------------------------
# * 0            /usr/lib/jvm/java-11-openjdk-amd64/bin/java      1111      auto mode
#   1            /usr/lib/jvm/java-11-openjdk-amd64/bin/java      1111      manual mode
#   2            /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java   1081      manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: ^C

# %%
# !java -version
# Out:
# openjdk version "11.0.25" 2024-10-15
# OpenJDK Runtime Environment (build 11.0.25+9-post-Ubuntu-1ubuntu122.04)
# OpenJDK 64-Bit Server VM (build 11.0.25+9-post-Ubuntu-1ubuntu122.04, mixed mode, sharing)

# %%
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/

# %%
import os
#Creating environment variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["JRE_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64/jre"
#os.environ["PATH"] += ":JAVAHOME/bin:JRE_HOME/bin:HADOOP_HOME/sbin"

# %%
# !apt-get purge openssh-server -qq

# %%
# !apt-get install openssh-server -qq > /dev/null

# %%
# !service ssh start
# Out:
#  * Starting OpenBSD Secure Shell server sshd
#    ...done.

# %%
# !grep Port /etc/ssh/sshd_config
# Out:
# #Port 22
# #GatewayPorts no

# %%
# !ssh-keygen -t rsa -P "" -f ~/.ssh/id_rsa
# Out:
# Generating public/private rsa key pair.
# Created directory '/root/.ssh'.
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:lKQN8bAz/60AAuTnABZya7S4odF4EYmgoi2obVj8KDg root@40332f82483a
# The key's randomart image is:
# +---[RSA 3072]----+
# |=+Bo  +..        |
# |=X.+   O .       |
# |B X . = =        |
# |=O =   =         |
# |* + o . S        |
# |o= o . . . .     |
# |E + .   . . .    |
# | +       . .     |
# |          .      |
# +----[SHA256]-----+
